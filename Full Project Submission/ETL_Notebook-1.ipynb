# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv(r"C:\Users\azouz\Downloads\spotify.csv.csv", encoding="latin1")
df.head(7)
# Out:
#    valence  year  acousticness                artists  danceability  \
# 0  518.000  2015       0.00543              ['BØRNS']        611.00
# 1  337.000  2015       0.06780  ['The Neighbourhood']        588.00
# 2  785.000  2015       0.01150        ['Tame Impala']          0.64
# 3  512.000  2015     205.00000    ['Chris Stapleton']        392.00
# 4  672.000  2015       0.03710             ['WILLOW']        764.00
# 5    0.100  2015     969.00000         ['Lord Huron']        545.00
# 6    0.137  2015       0.06710         ['The Weeknd']        585.00
#
#    duration_ms  energy  explicit                      id  instrumentalness  \
# 0       218107  797.00         0  2GiJYvgVaD2HtM8GqD9EgQ          0.001370
# 1       260173  521.00         0  5E30LdtzQTGqRvNd7l6kG5        149.000000
# 2       216320    0.74         1  6K4t31amVTZDgR3sKmwUJJ          0.006780
# 3       293293    0.37         0  3fqwjXwUGN6vbzIwvyFMhx          0.009600
# ...

# %%
pd.isnull(df).sum()
# Out:
# valence             0
# year                0
# acousticness        0
# artists             0
# danceability        0
# duration_ms         0
# energy              0
# explicit            0
# id                  0
# instrumentalness    0
# key                 0
# liveness            0
# loudness            0
# mode                0
# name                0
# popularity          0
# release_date        0
# speechiness         0
# tempo               0
# Genre               0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11845 entries, 0 to 11844
# Data columns (total 20 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   valence           11845 non-null  float64
#  1   year              11845 non-null  int64
#  2   acousticness      11845 non-null  float64
#  3   artists           11845 non-null  object
#  4   danceability      11845 non-null  float64
#  5   duration_ms       11845 non-null  int64
#  6   energy            11845 non-null  float64
#  7   explicit          11845 non-null  int64
#  8   id                11845 non-null  object
#  9   instrumentalness  11845 non-null  float64
#  10  key               11845 non-null  int64
#  11  liveness          11845 non-null  float64
#  12  loudness          11845 non-null  float64
#  13  mode              11845 non-null  int64
#  14  name              11845 non-null  object
#  15  popularity        11845 non-null  int64
# ...

# %%
(df["instrumentalness"] == 0).sum()
# Out:
# np.int64(5972)

# %%
df.duplicated().any()
# Out:
# np.False_

# %%
df['release_date'].dtype
# Out:
# dtype('O')

# %%
df['release_date'] = pd.to_datetime(df['release_date'], errors='coerce')

# %%
print(pd.api.types.is_datetime64_any_dtype(df['release_date']))
# Out:
# True

# %%
df['duration_ms'].head(10)
# Out:
# 0    218107
# 1    260173
# 2    216320
# 3    293293
# 4    196520
# 5    208212
# 6    242253
# 7    198293
# 8    179867
# 9    194613
# Name: duration_ms, dtype: int64

# %%
df['duration_min'] = df['duration_ms'] / 1000 / 60

# %%
df.head()
# Out:
#    valence  year  acousticness                artists  danceability  \
# 0    518.0  2015       0.00543              ['BØRNS']        611.00
# 1    337.0  2015       0.06780  ['The Neighbourhood']        588.00
# 2    785.0  2015       0.01150        ['Tame Impala']          0.64
# 3    512.0  2015     205.00000    ['Chris Stapleton']        392.00
# 4    672.0  2015       0.03710             ['WILLOW']        764.00
#
#    duration_ms  energy  explicit                      id  instrumentalness  \
# 0       218107  797.00         0  2GiJYvgVaD2HtM8GqD9EgQ          0.001370
# 1       260173  521.00         0  5E30LdtzQTGqRvNd7l6kG5        149.000000
# 2       216320    0.74         1  6K4t31amVTZDgR3sKmwUJJ          0.006780
# 3       293293    0.37         0  3fqwjXwUGN6vbzIwvyFMhx          0.009600
# 4       196520  705.00         0  0y60itmpH0aPKsFiGxmtnh          0.000019
#
#    ...  liveness   loudness  mode                        name popularity  \
# ...

# %%
df['duration_min'].dtype
# Out:
# dtype('float64')

# %%
df = df.drop(columns=['duration_ms'])

# %%
df.to_csv('cleaned_datadf.csv', index=False)
df
# Out:
#        valence  year  acousticness  \
# 0      518.000  2015       0.00543
# 1      337.000  2015       0.06780
# 2      785.000  2015       0.01150
# 3      512.000  2015     205.00000
# 4      672.000  2015       0.03710
# ...        ...   ...           ...
# 11840  608.000  2020       0.08460
# 11841    0.734  2020     206.00000
# 11842  637.000  2020     101.00000
# 11843  195.000  2020       0.00998
# 11844  642.000  2020     132.00000
#
#                                                  artists  danceability  \
# 0                                              ['BØRNS']       611.000
# 1                                  ['The Neighbourhood']       588.000
# 2                                        ['Tame Impala']         0.640
# 3                                    ['Chris Stapleton']       392.000
# 4                                             ['WILLOW']       764.000
# ...                                                  ...           ...
# ...

# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\azouz'

# %%
num_cols_for_outliers = df.select_dtypes(include=np.number).columns.tolist()

# %%
from tqdm import tqdm
import numpy as np

for col in tqdm(num_cols_for_outliers):
    q1 = df[col].quantile(0.25)
    q3 = df[col].quantile(0.75)
    iqr = q3 - q1
    lower = q1 - 1.5 * iqr
    upper = q3 + 1.5 * iqr
    
    df[col] = np.clip(df[col], lower, upper)
# Out:
# 100%|██████████| 14/14 [00:00<00:00, 52.53it/s]

# %%
df[num_cols_for_outliers].describe()
# Out:
#             valence          year  acousticness  danceability        energy  \
# count  11845.000000  11845.000000  11845.000000  11845.000000  11845.000000
# mean     328.476151   2017.535753    183.165190    430.492793    423.491408
# std      272.624371      1.705775    249.832192    321.675107    323.080276
# min        0.000000   2015.000000      0.000000      0.000000      0.000020
# 25%        0.790000   2016.000000      0.037200      0.798000      0.808000
# 50%      322.000000   2018.000000      0.819000    524.000000    491.000000
# 75%      525.000000   2019.000000    305.000000    696.000000    684.000000
# max      993.000000   2020.000000    762.444200    985.000000    999.000000
#
#            explicit  instrumentalness           key      liveness  \
# count  11845.000000      11845.000000  11845.000000  11845.000000
# mean       0.373913          0.000224      5.229548    121.057429
# std        0.483861          0.000366      3.598858    126.611504
# ...

# %%
df.to_csv('cleaned_data.csv', index=False)

# %%
df.dtypes
# Out:
# valence                    float64
# year                         int64
# acousticness               float64
# artists                     object
# danceability               float64
# energy                     float64
# explicit                     int64
# id                          object
# instrumentalness           float64
# key                          int64
# liveness                   float64
# loudness                   float64
# mode                         int64
# name                        object
# popularity                 float64
# release_date        datetime64[ns]
# speechiness                float64
# tempo                       object
# Genre                       object
# duration_min               float64
# dtype: object

# %%
df['artists'] = df['artists'].astype('string')
df['id'] = df['id'].astype('string')
df['name'] = df['name'].astype('string')
df['tempo'] = df['tempo'].astype('string')
df['Genr'] = df['tempo'].astype('string')
