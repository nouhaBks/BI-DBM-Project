# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv(r"C:\Users\azouz\Downloads\Spotify-cleaned_data_FINAL.csv", sep=';', encoding="latin1")

# %%
df.head(7)
# Out:
#    valence  year  acousticness                artists  danceability  energy  \
# 0    0.518  2015      0.005430              ['BØRNS']         0.611   0.797
# 1    0.337  2015      0.067800  ['The Neighbourhood']         0.588   0.521
# 2    0.785  2015      0.011500        ['Tame Impala']         0.640   0.740
# 3    0.512  2015      0.205000    ['Chris Stapleton']         0.392   0.370
# 4    0.672  2015      0.037100             ['WILLOW']         0.764   0.705
# 5    0.100  2015      0.762444         ['Lord Huron']         0.545   0.366
# 6    0.137  2015      0.067100         ['The Weeknd']         0.585   0.564
#
#    explicit                      id  instrumentalness  key  liveness  \
# 0         0  2GiJYvgVaD2HtM8GqD9EgQ          0.000883    6    0.2600
# 1         0  5E30LdtzQTGqRvNd7l6kG5          0.000883   10    0.1230
# 2         1  6K4t31amVTZDgR3sKmwUJJ          0.000883    4    0.1670
# 3         0  3fqwjXwUGN6vbzIwvyFMhx          0.000883    9    0.0821
# ...

# %%
n = 3  # number of decimal places

# Automatically select all float columns
float_cols = df.select_dtypes(include='float').columns

# Round them
df[float_cols] = df[float_cols].round(n)

# Check result
print(df.head())
# Out:
#    valence  year  acousticness                artists  danceability  energy  \
# 0    0.518  2015         0.005              ['BØRNS']         0.611   0.797
# 1    0.337  2015         0.068  ['The Neighbourhood']         0.588   0.521
# 2    0.785  2015         0.012        ['Tame Impala']         0.640   0.740
# 3    0.512  2015         0.205    ['Chris Stapleton']         0.392   0.370
# 4    0.672  2015         0.037             ['WILLOW']         0.764   0.705
#
#    explicit                      id  instrumentalness  key  liveness  \
# 0         0  2GiJYvgVaD2HtM8GqD9EgQ             0.001    6     0.260
# 1         0  5E30LdtzQTGqRvNd7l6kG5             0.001   10     0.123
# 2         1  6K4t31amVTZDgR3sKmwUJJ             0.001    4     0.167
# 3         0  3fqwjXwUGN6vbzIwvyFMhx             0.001    9     0.082
# 4         0  0y60itmpH0aPKsFiGxmtnh             0.000    3     0.094
#
#    loudness  mode                        name  popularity release_date  \
# ...

# %%
df.head(7)
# Out:
#    valence  year  acousticness                artists  danceability  energy  \
# 0    0.518  2015         0.005              ['BØRNS']         0.611   0.797
# 1    0.337  2015         0.068  ['The Neighbourhood']         0.588   0.521
# 2    0.785  2015         0.012        ['Tame Impala']         0.640   0.740
# 3    0.512  2015         0.205    ['Chris Stapleton']         0.392   0.370
# 4    0.672  2015         0.037             ['WILLOW']         0.764   0.705
# 5    0.100  2015         0.762         ['Lord Huron']         0.545   0.366
# 6    0.137  2015         0.067         ['The Weeknd']         0.585   0.564
#
#    explicit                      id  instrumentalness  key  liveness  \
# 0         0  2GiJYvgVaD2HtM8GqD9EgQ             0.001    6     0.260
# 1         0  5E30LdtzQTGqRvNd7l6kG5             0.001   10     0.123
# 2         1  6K4t31amVTZDgR3sKmwUJJ             0.001    4     0.167
# 3         0  3fqwjXwUGN6vbzIwvyFMhx             0.001    9     0.082
# ...

# %%
df.to_csv('Spotify_data.csv', index=False)

# %%
pd.options.display.float_format = '{:.3f}'.format

# %%
df.head(7)
# Out:
#    valence  year  acousticness                artists  danceability  energy  \
# 0    0.518  2015         0.005              ['BØRNS']         0.611   0.797
# 1    0.337  2015         0.068  ['The Neighbourhood']         0.588   0.521
# 2    0.785  2015         0.012        ['Tame Impala']         0.640   0.740
# 3    0.512  2015         0.205    ['Chris Stapleton']         0.392   0.370
# 4    0.672  2015         0.037             ['WILLOW']         0.764   0.705
# 5    0.100  2015         0.762         ['Lord Huron']         0.545   0.366
# 6    0.137  2015         0.067         ['The Weeknd']         0.585   0.564
#
#    explicit                      id  instrumentalness  key  liveness  \
# 0         0  2GiJYvgVaD2HtM8GqD9EgQ             0.001    6     0.260
# 1         0  5E30LdtzQTGqRvNd7l6kG5             0.001   10     0.123
# 2         1  6K4t31amVTZDgR3sKmwUJJ             0.001    4     0.167
# 3         0  3fqwjXwUGN6vbzIwvyFMhx             0.001    9     0.082
# ...

# %%
df.head(8)
# Out:
#    valence  year  acousticness                artists  danceability  energy  \
# 0    0.518  2015         0.005              ['BØRNS']         0.611   0.797
# 1    0.337  2015         0.068  ['The Neighbourhood']         0.588   0.521
# 2    0.785  2015         0.012        ['Tame Impala']         0.640   0.740
# 3    0.512  2015         0.205    ['Chris Stapleton']         0.392   0.370
# 4    0.672  2015         0.037             ['WILLOW']         0.764   0.705
# 5    0.100  2015         0.762         ['Lord Huron']         0.545   0.366
# 6    0.137  2015         0.067         ['The Weeknd']         0.585   0.564
# 7    0.189  2015         0.223      ['Bryson Tiller']         0.765   0.356
#
#    explicit                      id  instrumentalness  key  liveness  \
# 0         0  2GiJYvgVaD2HtM8GqD9EgQ             0.001    6     0.260
# 1         0  5E30LdtzQTGqRvNd7l6kG5             0.001   10     0.123
# 2         1  6K4t31amVTZDgR3sKmwUJJ             0.001    4     0.167
# ...

# %%
print(df.isna().sum())
# Out:
# valence              0
# year                 0
# acousticness         0
# artists              0
# danceability         0
# energy               0
# explicit             0
# id                   0
# instrumentalness     0
# key                  0
# liveness             0
# loudness             0
# mode                 0
# name                 0
# popularity           0
# release_date        36
# speechiness          0
# tempo                0
# Genre                0
# duration_min         0
# dtype: int64

# %%
df_clean = df.dropna()

# %%
print(df.isna().sum())
# Out:
# valence              0
# year                 0
# acousticness         0
# artists              0
# danceability         0
# energy               0
# explicit             0
# id                   0
# instrumentalness     0
# key                  0
# liveness             0
# loudness             0
# mode                 0
# name                 0
# popularity           0
# release_date        36
# speechiness          0
# tempo                0
# Genre                0
# duration_min         0
# dtype: int64

# %%
print(df_clean.isna().sum())
# Out:
# valence             0
# year                0
# acousticness        0
# artists             0
# danceability        0
# energy              0
# explicit            0
# id                  0
# instrumentalness    0
# key                 0
# liveness            0
# loudness            0
# mode                0
# name                0
# popularity          0
# release_date        0
# speechiness         0
# tempo               0
# Genre               0
# duration_min        0
# dtype: int64

# %%
df_clean.head(8)
# Out:
#    valence  year  acousticness                artists  danceability  energy  \
# 0    0.518  2015         0.005              ['BØRNS']         0.611   0.797
# 1    0.337  2015         0.068  ['The Neighbourhood']         0.588   0.521
# 2    0.785  2015         0.012        ['Tame Impala']         0.640   0.740
# 3    0.512  2015         0.205    ['Chris Stapleton']         0.392   0.370
# 4    0.672  2015         0.037             ['WILLOW']         0.764   0.705
# 5    0.100  2015         0.762         ['Lord Huron']         0.545   0.366
# 6    0.137  2015         0.067         ['The Weeknd']         0.585   0.564
# 7    0.189  2015         0.223      ['Bryson Tiller']         0.765   0.356
#
#    explicit                      id  instrumentalness  key  liveness  \
# 0         0  2GiJYvgVaD2HtM8GqD9EgQ             0.001    6     0.260
# 1         0  5E30LdtzQTGqRvNd7l6kG5             0.001   10     0.123
# 2         1  6K4t31amVTZDgR3sKmwUJJ             0.001    4     0.167
# ...

# %%
df_clean.to_csv('Spotify_data BI.csv', index=False)
